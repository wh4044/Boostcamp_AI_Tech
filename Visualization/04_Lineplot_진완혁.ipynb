# %% [markdown]
# # 기본 Line Plot
# ## Line plot이란?
# - **Line Plot**은 연속적으로 변화하는 값을 순서대로 점으로 나타내고, 이를 선으로 연결한 그래프이다.
#
#
# - 꺾은선 그래프, 선 그래프, line chart, line graph 등의 이름으로 사용된다.
#
#
# - 시간/순서에 대한 변화에 적합하여 추세를 살피기 위해 사용된다.
#     - 시계열 분석에 특화!
#
#
# - 신기하게 .line이 아니라 .plot()으로 사용한다.
#
# ## Line plot의 요소
# - 5개 이하의 선을 사용하는 것을 추천한다.
#     - 더 많은 선은 중첩으로 인해 가독성이 하락한다.
#
#
# - 그렇다면 이를 구별하는 요소는 어떤 게 있을까?
#     1. 색상(color)
#     2. 마커(marker, markersize)
#     3. 선의 종류(linestyle, linewidth)
#
# ## Line plot을 위한 전처리
# - 시시각각 변동하는 데이터는 Noise로 인해 패턴 및 추세 파악이 어렵다.
#
#
# - Noise의 인지적인 방해를 줄이기 위해 smoothing을 사용한다.
# ![image.png](attachment:image.png)
# 움직이는 trend만 볼 때 사용한다.

# %% [markdown]
# # 정확한 Line Plot
# ## 추세에 집숭
# - Bar plot과 다르게 꼭 축을 0에 초점을 둘 필요는 없다.
#     - 추세를 보기 위한 목적이기 때문이다.
#
#
# - 너무 구체적인 line plot보다는 생략된 line plot이 더 나을 수 있다.
#     - Grid, Annotate 등 모두 제거한다.
#     - 디테일한 정보는 표로 제공하는 것을 추천한다.
#
#
# - 생략되지 않는 선에서 범위를 조정하여 변화율 관찰(.set_ylim())
# ![image.png](attachment:image.png)
# 실제 값이 중요하면 왼쪽처럼 많은 정보를 표시하고, 몇년간의 흐름 또는 큰 틀만 보려면 오른쪽처럼 표현하면 된다.
#
# ## 간격
# - 규칙적인 간격이 아니라면 오해를 줄 수 있다!
#     - 그래프 상에서 규칙적일 때 : 기울기 정보의 오해(왼쪽 그래프)
#     - 그래프 상에서 간격이 다를 때 : 없는 데이터에 대해 있다고 오해(중앙 그래프)
#
#
# - 규칙적인 간격의 데이터가 아니라면 각 관측 값에 점으로 표시하여 오해를 줄이자(오른쪽 그래프)
# ![image-2.png](attachment:image-2.png)
#
# ## 보간
# - Line은 점을 이어 만드는 요소이다. -> 점과 점사이에 데이터가 없기에 이를 잇는 방법(보간)
#
#
# - 데이터의 error나 noise가 포함되어 있는 경우, 데이터의 이해를 돕는 방법
#     - Moving Average
#     - Smooth Curve with Scipy
#         - scipy.interpolate.make_interp_spline()
#         - scipy.interpolate.interp1d()
#         - scipy.ndimage.gaussia_filter1d()
#
#
# - Presentation에는 좋은 방법일 수 있으나
#     - 없는 데이터를 있다고 생각하게 할 수 있다.
#     - 작은 차이를 없을 수 있다.
#     - **일반적인 분석에서는 지양할 것!**
#
# ## 이중 축 사용
# - 한 plot에 대해 2개의 축을 **이중 축(dual axis)**라고 한다.
#
#
# - 같은 시간 축에 대해 서로 다른 종류의 데이터를 표현하기 위해서는 축이 2개가 필요하다.
#     - .twinx()를 사용한다.
#
#
# - 한 데이터에 대해 다른 단위(ex> radian과 degree)
#     - .secondary_xaxis(), .secondary_yaxis() 사용한다.
#
#
# - 2개의 plot을 그리는 것 >>>> 이중 축 사용
#     - 이중 축은 지양할 것.
#     ![image-3.png](attachment:image-3.png)
# 상관관계가 없는데 있는 것처럼 보이기 때문이다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ETC
# - 라인 끝 단에 레이블을 추가하면 식별에 도움이 된다.(범례 대신)
# ![image.png](attachment:image.png)

# %% [markdown]
# - Min/Max 정보(또는 원하는 포인트)는 추가해주면 도움이 될 수 있다.(annotation)
# ![image.png](attachment:image.png)

# %% [markdown]
# - 보다 연한 색을 사용하여 uncertainty 표현 가능 (신뢰구간, 분산 등)
# ![image.png](attachment:image.png)
