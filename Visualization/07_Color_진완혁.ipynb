# %% [markdown]
# # Color에 대한 이해
# ## 색이 중요한 이유
# - 위치와 **색**은 가장 효과적인 채널 구분이다.
#     - 위치는 시각화 방법에 따라 결정되고,
#     - 색은 우리가 직접적으로 골라야 한다.
#     - 사람이 공통적으로 색이 가지는 느낌은 다르다.
#     - 좋은 색과 색 배치는 예쁘다...!
#
# ## 화려함이 시각화의 전부는 아니다.
# - 심미적으로 화려한 것은 분명히 매력적이다.
#     - 하지만 화려함은 시각화의 일부 요소일 뿐 주가 되면 안 된다.
#
#
# - 가장 중요한 것은 독자에게 원하는 인사이트를 전달하는 것이다.
#     - 전하고 싶은 내용을 모두 전달했는가 + 그 과정에서 오해는 없었는가
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 색이 가지는 의미
# - 우리는 살명서 이미 많은 색을 사용했다.
#     - 높은 온도에서 파랑, 낮은 온도에는 빨강이라면???
#     - 카X오가 초록색, 네X버가 노란색이라면?
#     - 기존 정보와 느낌을 잘 활용하는 것이 중요하다.
#     - 만약 본인이 정말 감이 없다면?
#         - 다른 사례 스터디를 통해 색상을 선택한다
#         - ** 이미 사용하는 색에는 이유가 있다.**

# %% [markdown]
# # Color Palette의 종류
# ## 범주형(Categorical)
# - Discrete, Qualitative 등 다양한 이름으로 불린다.
#
#
# - **독립된 색상**으로 구성되어 **범주형 변수**에 사용.
#
#
# - 최대 10개의 색상까지 사용한다.
#     - 그 외에는 *기타*로 묶을 것.
#
#
# - **색의 차이**로 구분하는 것이 특징이다.
#     - 채도, 명도를 개별적 조정은 지양하자.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 연속형(Sequential)
# - 정렬된 값을 가지는 순서형, 연속형 변수에 적합하다.
#
#
# - **연속적인 색상**을 사용하여 값을 표현한다.
#     - 어두운 배경에서는 밝은 색이,
#     - 밝은 배경에서는 어두운 색이 큰 값을 표현한다.
#
#
# - 색상은 **단일 색조로 표현**하는 것이 좋다.
#
#
# - 균일한 색상 변화가 중요하다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 발산형(Diverge)
# - 연속형고 유사하지만 **중앙을 기준으로 발산한다.**
#     - 상반된 값(ex. 기온)이나,
#     - 서로 다른 2개(ex. 지지율)을 표현하는 데 적합하다.
#
#
# - 양 끝으로 갈수록 색이 진해진다.
#
#
# - 중앙의 색은 양쪽의 점에서 편향되지 않아야 한다.
#     - 꼭 무채색일 필요는 없다.
# ![image.png](attachment:image.png)
# 0도를 기준으로 기온들 표현한 것.

# %% [markdown]
# # 그 외 색 Tips
# ## 강조, 그리고 색상 대비
# - 데이터에서 다름을 보이기 위해 Highlighting 가능
#
#
# - 강조를 위한 방법 중 하나. **색상 대비(Color Contrast)**를 사용한다.
#     - **명도 대비** : 밝은 색과 어두운 색을 배치하면서 밝은 색은 더 밝게, 어두운 색은 더 어둡게 보인다.(회색검정)
#     - **색상 대비** : 가까운 색은 차이가 더 크게 보인다.(파랑보라, 빨강보라)
#     - **채도 대비** : 채도의 차이, 채도가 더 높아보임(회색주황)
#     - **보색 대비** : 정반대 색상을 사용하면 더 선명해 보인다.(빨강초록)

# %% [markdown]
# ## 색각 이상
# - 삼원색 중에 특정 색을 감지 못하면 **색명**
#
#
# - 부분적 인지 이상이 있다면 **색약**
#
#
# - 색 인지가 중요한 분야(과학/연구 등)에 있어서는 이에 대한 고려가 필수
# ![image.png](attachment:image.png)
