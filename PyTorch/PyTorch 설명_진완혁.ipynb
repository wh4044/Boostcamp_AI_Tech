# %% [markdown]
# ### 딥러닝을 할 때 코드를 처음부터 다 짜면 죽을 수도 있다.
# ### 그렇기 때문에 남이 만들어 놓은 프레임 워크를 사용한다.
# #### (자료도 많고, 관리도 잘 되고, 표준이다..!)
#
# ### 그 중 facebook에서 만든 PyTorch와 Google에서 만든 TensorFlow가 제일 많이 쓰인다.

# %% [markdown]
# ## - Computational Graph 연산의 과정을 그래프로 표현
# ![image.png](attachment:image.png)

# %% [markdown]
# ## - Define and Run(TF)
# ## : 그래프를 먼저 정의 -> 실행시점에 데이터 feed
#
# ## - Define by Run(PyTorch)
# ## : 실행을 하면서 그래프를 생성하는 방식

# %% [markdown]
# # Why PyTorch?
# - Define by Run의 장점 : 즉시 확인 가능 -> pythonic code
# - GPU support, Good API and community
# - 사용하기 편한 장점이 가장 큼
# - TF는 production과 scalability의 장점
#
# # PyTorch의 핵심
# ### Numpy + AutoGrad + Function
# - Numpy 구조를 가지는 Tensor 객체로 array 표현
# - 자동미분을 지원하여 DL 연산을 지원
# - 다양한 형태의 DL을 지원하는 함수와 모델을 지원함.

# %% [markdown]
# # *Reference*

# %% [markdown]
# 1. [Deep Learning 프레임워크 비교](https://en.wikipedia.org/wiki/Comparison_of_deep-learning_software)
#
# 프레임워크가 굉장히 많다. 하지만 TF와 PyTorch가 제일 많이 쓰임.

# %% [markdown]
# 2. [PyTorch로 시작하는 딥러닝 입문](https://wikidocs.net/book/2788)
#
# (위키독스) PyTorch를 사용하여 딥러닝에 입문하는 것을 목표로 둠.
#
# 자연어, CNN, RNN 내용 있다.

# %% [markdown]
# 3. [WELCOME TO PYTORCH TUTORIALS](https://pytorch.org/tutorials/)
#
# PyTorch를 익힐 수 있는 공식 사이트. Quick Start 예제를 통해 사용법을 익히거나
# 함수 사용법을 찾아볼 수 있다.
