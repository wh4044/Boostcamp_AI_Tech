# %% [markdown]
# ### 조건부 확률이란?
# - 베이즈 통계학을 이해하기 위해선 조건부확률의 개념을 이해해야 한다.
# - 베이즈 정리는 조건부확률을 이용하여 **정보를 갱신하는 방법**을 알려준다.
# ![image.png](attachment:image.png)
# 조건부확률 P(A|B)는 사건 B가 일어난 상황에서 사건 A가 발생할 확률을 의미한다.
# ![image-2.png](attachment:image-2.png)
# A 라는 새로운 정보가 주어졌을 때 P(B)로부터 P(B|A)를 계산하는 방법을 제공한다.

# %% [markdown]
# ----
# ![image.png](attachment:image.png)
# - D는 새로 관찰하는 데이터
# - 세타는 모델링하는 이벤트(계산하고 싶은 파라미터, 모수)
# - 가능도는 현재 주어진 파라미터, 모수, 가정에서 이 데이터가 관찰될 확률
# - Evidence의 역할은 데이터 전체의 분포

# %% [markdown]
#  ![image.png](attachment:image.png)
#  세타를 covid-99 발병 사건으로 정의(관찰 불가)하고, D를 테스트 결과라고 정의(관찰 가능)한다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# 질병에 걸렸다고 검진결과가 나왔을 때 실제로 covid-99에 감염되었을 확률 : **0.916**
#
# 만약 오탐율(False alarm)이 오르면 테스트의 정밀도(Precision)가 떨어진다.
# (실제로 걸리지 않았을 때 오검진될 확률이 높으면)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2종 오류 : 질병이 아니다 라고 했는데 실제로는 질병일 경우
#
# 사전확률을 모를 때는 베이즈 통계를 적용하기 힘들고, 실제로 모를 때는 보통 임의로 사전확률을 설정하지만 분석 효과가 떨어진다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 베이즈 정리를 통한 정보의 갱신
# - 베이즈 정리를 통해 새로운 데이터가 들어왔을 때 앞서 계산한 사후확률을 사전확률로 사용하여 **갱신된 사후확률을 계산**할 수 있다.
#  ![image.png](attachment:image.png)

# %% [markdown]
# #### - 앞서 covid-99 판정을 받은 사람이 두 번째 검진을 받았을 때도 양성이 나왔을 때 진짜 covid-99에 걸렸을 확률은?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 조건부 확률은 유용한 통계적 해석을 제공하지만 **인과관계(causality)**를 추론할 때 함부로 사용해서는 안 된다.
# - 인과관계는 **데이터 분포의 변화에 강건한 예측모형**을 만들 때 필요.
# ![image.png](attachment:image.png)

# %% [markdown]
# - 인과관계를 알아내기 위해서는 중첩요인(confounding factor)의 효과를 제거하고 원인에 해당하는 변수만의 인과관계를 계산해야 한다.
#
# ex) 키와 지능의 상관관계
